# %%
import sys
sys.path.append('../src')
from product_dataset_analyzer import load_product_data, explore_dataset, create_visualizations

# %%
# Load & Explore Dataset
df = load_product_data()
explore_dataset(df)
# Out:
# === General Dataset Information ===
#
# Dataset Dimensions:
# Rows: 5000, Columns: 11
#
# === Detailed Column Information ===
#
# Column Names:
# 1. main_category
# 2. title
# 3. average_rating
# 4. rating_number
# 5. features
# 6. description
# 7. price
# 8. store
# 9. categories
# 10. details
# 11. parent_asin
#
# Data Types by Column:
# main_category: object
# title: object
# average_rating: float64
# rating_number: int64
# features: object
# description: object
# price: float64
# store: object
# categories: object
# details: object
# parent_asin: object
#
# First rows of each column:
#          main_category                                              title  \
# 0  Musical Instruments  Ernie Ball Mondo Slinky Nickelwound Electric G...
# 1  Musical Instruments  BONAOK Wireless Bluetooth Karaoke Microphone, ...
# 2       Camera & Photo  Boya BYM1 by Shotgun Video Microphone by-M1 Ul...
# 3  Musical Instruments  D'Addario Guitar Strings - Phosphor Bronze Aco...
# ...

# %%
# Create Graphs to visualize the dataset & Correlation Matrix
create_visualizations(df)
